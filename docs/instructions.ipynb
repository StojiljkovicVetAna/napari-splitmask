# %%
from IPython.display import Image
import napari
from napari.utils.notebook_display import nbscreenshot
viewer=napari.Viewer()
# Out:
# napari.manifest -> 'napari-splitmask-testAna' could not be imported: Cannot find module 'napari_splitmask_testana' declared in entrypoint: 'napari_splitmask_testana:napari.yaml'
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 2172x1352+212+16 (frame: 2194x1408+201-29) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 3260x1170+215+30 (frame: 3282x1226+204-15) margins: 11, 45, 11, 11 minimum size: 374x552 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=770,1160 maxtrack=0,0)

# %% [markdown]
# # Step-by-step guide
# 7 steps are necessary to perform intensity measurements with the napari-splitmask plugin.Although the steps are self-explanatory, here you can find some important considerations for each step of the analysis.
#
# To start using napari-splitmask activate the environment containing the napari-splitmask installation and open a napari GUI by typing napari in the terminal. In the GUI open the Plugins/napari-splitmask.
#
# *In the example below I have called the environment 'splitmask-test'*

# %%
Image('images/anaconda_Prompt.png')

# %%
nbscreenshot(viewer)
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1156+0+34 (frame: 1942x1212-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1094+0+34 (frame: 1942x1150-11-11) margins: 11, 45, 11, 11 minimum size: 754x578 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1530,1212 maxtrack=0,0)

# %% [markdown]
# Drag-and-drop the images that you wamt to analyze. The image should be a time-lapse. If you have many channels, import the different channels as single time-lapse images.
#
# ```{warning}
# The image should not contain 'mask' in its name, because this is a filtering criterion to import them in the different drop-down menus. If this is the case, you can rename the images directly in napari for the analysis.
# ```

# %% [markdown]
# ## 1. Add a point of interest
# To add the point of interest you have two different options:
#
# - You can manually add a point of interest using the 'Add ROI' button. This will create a point layer in napari called 'point of interest'. You can now select the (+) button and add a point where you want the splitmask to be generated.
#
# - Alternatively, if you have already a label image, you can drag-and-drop it in napari together with the images to analyze.<br/>
# *In this case, splitmask will calculate a center of mass for your label, and use it as the coordinates to generate the splitmask geometry.*
#
# ```{warning}
# Make sure that the label image is imported correctly as label. If this is not the case you can right-click on the image, and select the option "Convert to Labels"
#
# ```

# %%
Image('images/point_layer.png')

# %% [markdown]
# ## 2. Select the point or label layer from which the mask will be generated:
# Even if you have a label, maybe you have decided to add a point of interest manually, so here is the option where you have to decide, which layer will be used to generate the splitmask. Select from the drop down menu.

# %% [markdown]
# ## 3. Generate a sector of the desired geometry using the tabs:
# Depending on what geometry you want to generate, there are different parameters that you have to set. This is why the splitmask geometries are are displayed on different tabs. You can also decide to generate different geometries. When you hit the generate button napari-splitmask will produce a label layer with the selected geometry.

# %%
Image('images/napari-splitmask_shapes.png')

# %% [markdown]
# ### radial sector
# Parameters:
# - *sector width* is the radius of each sector
# - *number of sectors* defines how many sectors will compose this geometry
#
# After the selection, hit the *Generate radial sector!* button. When the mask is generated, you can adjust it using the spin buttons.
#
#
# ```{warning}
# I  f the geometry doesn't update live make sure that the correct layer is selected in step 2.
# ```

# %%
Image('images/radial_sector.png')

# %% [markdown]
# ### angular sector
# Parameters:
# - *angle width* is represented in degrees, and its range is 1-360°
# - *sector radius* is the radius of the circle that will be generated
#
# ```{warning}
# The last sector will not be generated, unless 360° is a multiple of the angle width you have select.
# ```

# %%
Image('images/angular_sector.png')
# Out:
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1108+0+34 (frame: 1942x1164-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1094+0+34 (frame: 1942x1150-11-11) margins: 11, 45, 11, 11 minimum size: 374x554 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=770,1164 maxtrack=0,0)
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1112+0+34 (frame: 1942x1168-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1094+0+34 (frame: 1942x1150-11-11) margins: 11, 45, 11, 11 minimum size: 374x556 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=770,1168 maxtrack=0,0)
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped
# c:\Users\anast\miniconda3\envs\mySPLITMASK\lib\site-packages\napari\layers\base\base.py:1632: RuntimeWarning: invalid value encountered in cast
#   corners[:, displayed_axes] = data_bbox_clipped

# %% [markdown]
# In the following example an angle of 50° was selected, therefore only 7 complete angular sectors were generated.

# %%
Image('images/angular_missing.png')
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1156+0+34 (frame: 1942x1212-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1094+0+34 (frame: 1942x1150-11-11) margins: 11, 45, 11, 11 minimum size: 754x578 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1530,1212 maxtrack=0,0)
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1156+0+34 (frame: 1942x1212-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1094+0+34 (frame: 1942x1150-11-11) margins: 11, 45, 11, 11 minimum size: 754x578 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1530,1212 maxtrack=0,0)

# %% [markdown]
# ### circular sector
# This geometry is very similar to the angular sector but it is annular, so that you will need to setup the thickness of the generated ring.
#
# Parameters:
# - *angle width* is represented in degrees, and its range is 1-360°
# - *sector radius* is the radius of the circle that will be generated
# - *ring width* determines the thickness of the ring

# %% [markdown]
# ## 4. Select the channel to analyze:
# If you have imported different image channels to analyze, here you have to input on which image you want to apply the splitmask intensity measurements.

# %% [markdown]
# ## 5. Select the sector mask to apply:
# In step 5, you might have generated different sectors, therefore here you need to select which mask will be used to calculate the intensities.
#
# ```{warning}
# Here is where the 'mask' filtering is applied, your mask will be displayed in this drop-down menu, only if it contains the word 'mask'. Please, even if you decide to rename this layer, keep the word "mask" in the new name.
# ```

# %% [markdown]
# ## 6. Compute plot
# This function will generate a line plot in a separate window, with the time points on the x-axis and the intensity of the different sectors on the y-axis.
# The colors of the lines corresponds to the colors of the sectors.

# %% [markdown]
# ## 7. Save plot data
# Use this option to save the generated data, you will be asked to select a folder to export the saved results. The saving automatically includes:
# - the .csv file of the plot data
# - the mask geometry used for the measurements. This can later be reimported as a label layer in napari
# - the screenshot of the napari viewer main window, so that you can document the overlap of the mask and the analyzed images.
